# %% [markdown]
# # PRINCIPLE COMPONENT ANALYSIS (PCA)

# %% [markdown]
# # Task 1: Exploratory Data Analysis (EDA):

# %%
import pandas as pd
df = pd.read_csv('C:\\Users\\user\\Desktop\\excler assinements\\PCA\\wine.csv')
df
# Out:
#      Type  Alcohol  Malic   Ash  Alcalinity  Magnesium  Phenols  Flavanoids  \
# 0       1    14.23   1.71  2.43        15.6        127     2.80        3.06
# 1       1    13.20   1.78  2.14        11.2        100     2.65        2.76
# 2       1    13.16   2.36  2.67        18.6        101     2.80        3.24
# 3       1    14.37   1.95  2.50        16.8        113     3.85        3.49
# 4       1    13.24   2.59  2.87        21.0        118     2.80        2.69
# ..    ...      ...    ...   ...         ...        ...      ...         ...
# 173     3    13.71   5.65  2.45        20.5         95     1.68        0.61
# 174     3    13.40   3.91  2.48        23.0        102     1.80        0.75
# 175     3    13.27   4.28  2.26        20.0        120     1.59        0.69
# 176     3    13.17   2.59  2.37        20.0        120     1.65        0.68
# 177     3    14.13   4.10  2.74        24.5         96     2.05        0.76
#
# ...

# %%
# Basic data exploration
print(df.head())
# Out:
#    Type  Alcohol  Malic   Ash  Alcalinity  Magnesium  Phenols  Flavanoids  \
# 0     1    14.23   1.71  2.43        15.6        127     2.80        3.06
# 1     1    13.20   1.78  2.14        11.2        100     2.65        2.76
# 2     1    13.16   2.36  2.67        18.6        101     2.80        3.24
# 3     1    14.37   1.95  2.50        16.8        113     3.85        3.49
# 4     1    13.24   2.59  2.87        21.0        118     2.80        2.69
#
#    Nonflavanoids  Proanthocyanins  Color   Hue  Dilution  Proline
# 0           0.28             2.29   5.64  1.04      3.92     1065
# 1           0.26             1.28   4.38  1.05      3.40     1050
# 2           0.30             2.81   5.68  1.03      3.17     1185
# 3           0.24             2.18   7.80  0.86      3.45     1480
# 4           0.39             1.82   4.32  1.04      2.93      735

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Type             178 non-null    int64
#  1   Alcohol          178 non-null    float64
#  2   Malic            178 non-null    float64
#  3   Ash              178 non-null    float64
#  4   Alcalinity       178 non-null    float64
#  5   Magnesium        178 non-null    int64
#  6   Phenols          178 non-null    float64
#  7   Flavanoids       178 non-null    float64
#  8   Nonflavanoids    178 non-null    float64
#  9   Proanthocyanins  178 non-null    float64
#  10  Color            178 non-null    float64
#  11  Hue              178 non-null    float64
#  12  Dilution         178 non-null    float64
#  13  Proline          178 non-null    int64
# dtypes: float64(11), int64(3)
# memory usage: 19.6 KB
# None

# %%
print(df.describe())
# Out:
#              Type     Alcohol       Malic         Ash  Alcalinity   Magnesium  \
# count  178.000000  178.000000  178.000000  178.000000  178.000000  178.000000
# mean     1.938202   13.000618    2.336348    2.366517   19.494944   99.741573
# std      0.775035    0.811827    1.117146    0.274344    3.339564   14.282484
# min      1.000000   11.030000    0.740000    1.360000   10.600000   70.000000
# 25%      1.000000   12.362500    1.602500    2.210000   17.200000   88.000000
# 50%      2.000000   13.050000    1.865000    2.360000   19.500000   98.000000
# 75%      3.000000   13.677500    3.082500    2.557500   21.500000  107.000000
# max      3.000000   14.830000    5.800000    3.230000   30.000000  162.000000
#
#           Phenols  Flavanoids  Nonflavanoids  Proanthocyanins       Color  \
# count  178.000000  178.000000     178.000000       178.000000  178.000000
# mean     2.295112    2.029270       0.361854         1.590899    5.058090
# ...

# %%
df.isnull().sum()
# Out:
# Type               0
# Alcohol            0
# Malic              0
# Ash                0
# Alcalinity         0
# Magnesium          0
# Phenols            0
# Flavanoids         0
# Nonflavanoids      0
# Proanthocyanins    0
# Color              0
# Hue                0
# Dilution           0
# Proline            0
# dtype: int64

# %% [raw]
# there is no missing data found

# %% [raw]
# Examine the distribution of features using histograms, box plots, or density plots.

# %%
#histogram
import matplotlib.pyplot as plt

df.hist(figsize=(20, 10), bins=15)
plt.show()

# %%
# box plot
df.boxplot(figsize=(20, 10))
plt.show()

# %% [raw]
# no outliers were found

# %%
# Distribution of features using density plots
df.plot(kind='density', subplots=True, layout=(4, 4), figsize=(20, 8))
plt.show()

# %%
# creating corelation matrix

corr_matrix = df.corr()
corr_matrix
# Out:
#                      Type   Alcohol     Malic       Ash  Alcalinity  \
# Type             1.000000 -0.328222  0.437776 -0.049643    0.517859
# Alcohol         -0.328222  1.000000  0.094397  0.211545   -0.310235
# Malic            0.437776  0.094397  1.000000  0.164045    0.288500
# Ash             -0.049643  0.211545  0.164045  1.000000    0.443367
# Alcalinity       0.517859 -0.310235  0.288500  0.443367    1.000000
# Magnesium       -0.209179  0.270798 -0.054575  0.286587   -0.083333
# Phenols         -0.719163  0.289101 -0.335167  0.128980   -0.321113
# Flavanoids      -0.847498  0.236815 -0.411007  0.115077   -0.351370
# Nonflavanoids    0.489109 -0.155929  0.292977  0.186230    0.361922
# Proanthocyanins -0.499130  0.136698 -0.220746  0.009652   -0.197327
# Color            0.265668  0.546364  0.248985  0.258887    0.018732
# Hue             -0.617369 -0.071747 -0.561296 -0.074667   -0.273955
# Dilution        -0.788230  0.072343 -0.368710  0.003911   -0.276769
# ...

# %%
# Investigate specific correlations
m1 = corr_matrix['Flavanoids']['Phenols']
print(f"Correlation between Flavanoids content and Phenols: {m1:.2f}")

m2 = corr_matrix['Dilution']['Flavanoids']
print(f"Correlation between Dilution and Flavanoids: {m2:.2f}")

m3 = corr_matrix['Proline']['Alcohol']
print(f"Correlation between alcohol content and Proline: {m3:.2f}")

m4 = corr_matrix['Color']['Alcohol']
print(f"Correlation between Color and Alcohol: {m4:.2f}")
# Out:
# Correlation between Flavanoids content and Phenols: 0.86
# Correlation between Dilution and Flavanoids: 0.79
# Correlation between alcohol content and Proline: 0.64
# Correlation between Color and Alcohol: 0.55

# %% [markdown]
# # Task 2: Dimensionality Reduction with PCA:

# %% [raw]
# Standardize the features to ensure they have a mean of 0 and a standard deviation of Implement PCA to reduce the dimensionality of the dataset.

# %%
# Standardized the features
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaled_data = scaler.fit_transform(df)

# %%
# Implementing PCA
from sklearn.decomposition import PCA

pca = PCA()
pca.fit(scaled_data)
# Out:
# PCA()

# %% [raw]
# Determine the optimal number of principal components using techniques like scree plot or cumulative explained variance.

# %%
# Determining the optimal number of principal components
import numpy as np
explained_variance_ratio = pca.explained_variance_ratio_
cumulative_explained_variance = np.cumsum(explained_variance_ratio)

# %%
# Scree plot to visualize the explained variance
plt.figure(figsize=(10, 6))
plt.plot(range(1, len(explained_variance_ratio) + 1), explained_variance_ratio, marker='o')
plt.xlabel("Principal Component")
plt.ylabel("Explained Variance Ratio")
plt.title("Scree Plot")
plt.show()

# %%
#Transforming  the original dataset into the principal components

n_components = 3
pca = PCA(n_components=n_components)
pca_data = pca.fit_transform(scaled_data)

# %% [markdown]
# # Task 3: Clustering with Original Data:

# %% [raw]
# Apply a clustering algorithm (e.g., K-means) to the original dataset.

# %%
# K-means clustering with 3 clusters

from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=3)
kmeans.fit(df)
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# KMeans(n_clusters=3)

# %%
# Adding cluster labels to the DataFrame
df['Cluster'] = kmeans.labels_

# %% [raw]
# Visualize the clustering results using appropriate plots.

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df['Alcohol'], df['Malic'], c=df['Cluster'], cmap='viridis')
plt.xlabel('Alcohol')
plt.ylabel('Malic')
plt.title('K-means Clustering with 3 Clusters')
plt.show()

# %% [raw]
# Evaluating  the clustering performance using silhouette score

# %%
from sklearn.metrics import silhouette_score

silhouette_score = silhouette_score(df, df['Cluster'])
print('Silhouette score:', silhouette_score)
# Out:
# Silhouette score: 0.5711272461368314

# %% [raw]
# Evaluating  the clustering performance using Davies–Bouldin index

# %%
from sklearn.metrics import davies_bouldin_score

davies_bouldin_score = davies_bouldin_score(df, df['Cluster'])
print('Davies–Bouldin index:', davies_bouldin_score)
# Out:
# Davies–Bouldin index: 0.5342631450921205

# %% [markdown]
# # Task 4: Clustering with PCA Data:

# %%
#  Applying  the same clustering algorithm to the PCA-transformed dataset.

# K-means clustering with 3 clusters on PCA-transformed data 

kmeans = KMeans(n_clusters=3)
kmeans.fit(pca_data)

# Adding the  cluster labels to the DataFrame here 

df['Cluster_PCA'] = kmeans.labels_
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
plt.figure(figsize=(10, 6))
plt.scatter(pca_data[:, 0], pca_data[:, 1], c=df['Cluster_PCA'], cmap='viridis')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('K-means Clustering with 3 Clusters on PCA-transformed data')
plt.show()

# %% [raw]
# # Compare the clustering results from PCA-transformed data with those from the original dataset.

# %%
print('Clustering results on original data:')
print(df.groupby('Cluster').mean())

print('Clustering results on PCA-transformed data:')
print(df.groupby('Cluster_PCA').mean())
# Out:
# Clustering results on original data:
#              Type    Alcohol     Malic       Ash  Alcalinity   Magnesium  \
# Cluster
# 0        1.021277  13.804468  1.883404  2.426170   17.023404  105.510638
# 1        2.258065  12.929839  2.504032  2.408065   19.890323  103.596774
# 2        2.275362  12.516667  2.494203  2.288551   20.823188   92.347826
#
#           Phenols  Flavanoids  Nonflavanoids  Proanthocyanins     Color  \
# Cluster
# 0        2.867234    3.014255       0.285319         1.910426  5.702553
# 1        2.111129    1.584032       0.388387         1.503387  5.650323
# 2        2.070725    1.758406       0.390145         1.451884  4.086957
#
#               Hue  Dilution      Proline  Cluster_PCA
# Cluster
# 0        1.078298  3.114043  1195.148936     0.000000
# 1        0.883968  2.365484   728.338710     1.241935
# 2        0.941159  2.490725   458.231884     1.275362
# Clustering results on PCA-transformed data:
# ...

# %% [markdown]
# # Comparison , Analysis and conclusion

# %% [raw]
#
#  from all above results  these are main findings
#
#  The correlation matrix shows that some features are highly correlated,such as alcohol and malic acid.
#
#  K-means clustering with 3 clusters on the original data and PCA-transformed data results in different cluster assignments.
#
# The results show that the clustering on the PCA-transformed data has a higher silhouette score and a lower Davies–Bouldin index.
#
# This suggests that the clustering on the PCA-transformed data is better than the clustering on the original data.
#
# PCA can be used to reduce the dimensionality of the dataset from 13 features to 3 principal components,
#     while preserving most of the variance.
